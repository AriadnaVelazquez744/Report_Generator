# %% [markdown]
# # Test de Vectorización de Artículos
#
# Este notebook prueba la vectorización de artículos usando TF-IDF y guarda los vectores en los archivos JSON.

# %%
import logging
import sys
from pathlib import Path

# Configurar logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)

# Asegurar que podemos importar desde src
PROJECT_ROOT = Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(f"Directorio de trabajo: {PROJECT_ROOT}")
# Out:
# Directorio de trabajo: /home/ari/Collage/04-Forth_Year/Preimer_Semestre/PL/Final_Proj/Report_Generator

# %% [markdown]
# ## 1. Importar módulos necesarios

# %%
from src.recommendation.vectorizer import NewsVectorizer
from src.recommendation.vectorize_articles import vectorize_articles_directory

print("✅ Módulos importados correctamente")
# Out:
# ✅ Módulos importados correctamente

# %% [markdown]
# ## 2. Crear vectorizador

# %%
# Crear vectorizador con configuración estándar
vectorizer = NewsVectorizer(
    max_features=3000,
    ngram_range=(1, 2)
)

print(f"✅ Vectorizador creado")
print(f"   - max_features: {vectorizer.vectorizer.max_features}")
print(f"   - ngram_range: {vectorizer.vectorizer.ngram_range}")
print(f"   - norm: {vectorizer.vectorizer.norm}")
print(f"   - sublinear_tf: {vectorizer.vectorizer.sublinear_tf}")
# Out:
# ✅ Vectorizador creado
#    - max_features: 3000
#    - ngram_range: (1, 2)
#    - norm: l2
#    - sublinear_tf: True

# %% [markdown]
# ## 3. Vectorizar artículos en data_example
#
# **Ajusta la dirección aquí si es necesario:**

# %%
# Dirección de los artículos de prueba
articles_directory = "Data/Data_articles/Data_articles3"

# Vectorizar
vectorized_count = vectorize_articles_directory(
    directory_path=articles_directory,
    news_vectorizer=vectorizer
)

print(f"\n✅ Vectorización completada")
print(f"   Artículos vectorizados: {vectorized_count}")
# Out:
# 2025-12-13 15:17:25,216 - src.recommendation.vectorize_articles - INFO - Cargando 22 artículos desde data_example...
# 2025-12-13 15:17:25,269 - src.recommendation.vectorize_articles - INFO - ✅ 22 artículos cargados
# 2025-12-13 15:17:25,271 - src.recommendation.vectorize_articles - INFO - Extrayendo textos limpios...
# Extrayendo textos: 100%|██████████| 22/22 [00:00<00:00, 11929.50it/s]
# 2025-12-13 15:17:25,295 - src.recommendation.vectorize_articles - INFO - ✅ 22 artículos listos para vectorizar
# 2025-12-13 15:17:25,297 - src.recommendation.vectorize_articles - INFO - Vectorizando 22 artículos con TF-IDF...
# 2025-12-13 15:17:25,425 - src.recommendation.vectorize_articles - INFO - ✅ Matriz de artículos: (22, 1340)
# 2025-12-13 15:17:25,426 - src.recommendation.vectorize_articles - INFO - Guardando vectores en archivos JSON...
# Guardando vectores: 100%|██████████| 22/22 [00:00<00:00, 45.02it/s]
# 2025-12-13 15:17:25,919 - src.recommendation.vectorize_articles - INFO - ✅ 22/22 artículos vectorizados y guardados
# ✅ Vectorización completada
#    Artículos vectorizados: 22

# %% [markdown]
# ## 4. Verificar que los vectores se guardaron

# %%
import json
import os

# Verificar un artículo
article_files = sorted([f for f in os.listdir(articles_directory) 
                        if f.startswith('article_') and f.endswith('.json')])

if article_files:
    # Leer el primer artículo
    first_article_path = os.path.join(articles_directory, article_files[0])
    with open(first_article_path, 'r', encoding='utf-8') as f:
        article = json.load(f)
    
    print(f"✅ Verificación del archivo: {article_files[0]}")
    print(f"   - Tiene 'vector': {'vector' in article}")
    print(f"   - Tiene 'vectorization_metadata': {'vectorization_metadata' in article}")
    
    if 'vector' in article:
        print(f"   - Dimensión del vector: {len(article['vector'])}")
        print(f"   - Primeros 5 valores: {article['vector'][:5]}")
    
    if 'vectorization_metadata' in article:
        metadata = article['vectorization_metadata']
        print(f"   - Metadata:")
        for key, value in metadata.items():
            print(f"     - {key}: {value}")
else:
    print("❌ No se encontraron artículos en el directorio")
# Out:
# ✅ Verificación del archivo: article_1.json
#    - Tiene 'vector': True
#    - Tiene 'vectorization_metadata': True
#    - Dimensión del vector: 1340
#    - Primeros 5 valores: [0.0, 0.0, 0.0, 0.054550000395282995, 0.07068287508460316]
#    - Metadata:
#      - vectorizer_type: TF-IDF
#      - vector_dimension: 1340
#      - processing_timestamp: 2025-12-13T15:17:25.428629

# %% [markdown]
# ## 5. Información del vectorizador

# %%
print(f"✅ Información del vectorizador después de fit:")
print(f"   - Fitted: {vectorizer.fitted}")
print(f"   - Vocabulary size: {len(vectorizer.get_vocabulary())}")
print(f"   - Feature names count: {len(vectorizer.get_feature_names())}")
print(f"   - Min DF: {vectorizer.vectorizer.min_df}")
print(f"   - Max DF: {vectorizer.vectorizer.max_df}")
# Out:
# ✅ Información del vectorizador después de fit:
#    - Fitted: True
#    - Vocabulary size: 1340
#    - Feature names count: 1340
#    - Min DF: 2
#    - Max DF: 0.85

# %% [markdown]
# ## 6. Cargar artículos vectorizados para verificar

# %%
# Cargar algunos artículos y verificar que tienen vectores
loaded_articles = []

for filename in article_files[:3]:  # Primeros 3 artículos
    file_path = os.path.join(articles_directory, filename)
    with open(file_path, 'r', encoding='utf-8') as f:
        article = json.load(f)
        loaded_articles.append({
            'filename': filename,
            'has_vector': 'vector' in article,
            'vector_dim': len(article.get('vector', [])),
            'title': article.get('title', 'N/A')[:50]
        })

print(f"✅ Artículos cargados y verificados:")
for item in loaded_articles:
    print(f"\n   {item['filename']}")
    print(f"   - Tiene vector: {item['has_vector']}")
    print(f"   - Dimensión: {item['vector_dim']}")
    print(f"   - Título: {item['title']}...")
# Out:
# ✅ Artículos cargados y verificados:
#
#    article_1.json
#    - Tiene vector: True
#    - Dimensión: 1340
#    - Título: Ataques israelíes contra Gaza dejan al menos 38 pa...
#
#    article_11.json
#    - Tiene vector: True
#    - Dimensión: 1340
#    - Título: Nicaragua conmemora 204 años de independencia - te...
#
#    article_12.json
#    - Tiene vector: True
#    - Dimensión: 1340
#    - Título: Flotilla humanitaria hacia Gaza refuerza seguridad...

# %% [markdown]
# ## 7. Resumen

# %%
print(f"\n" + "="*80)
print(f"📊 RESUMEN DE VECTORIZACIÓN")
print(f"="*80)
print(f"\n✅ Directorio: {articles_directory}")
print(f"✅ Artículos vectorizados: {vectorized_count}")
print(f"✅ Dimensión de vectores: {len(article.get('vector', []))}")
print(f"✅ Vectorizador ajustado: {vectorizer.fitted}")
print(f"\n💾 Los vectores han sido guardados en los archivos JSON")
print(f"🔄 Ahora puedes usar estos vectores en news_update_&_process.py")
print(f"\n" + "="*80)
# Out:
# ================================================================================
# 📊 RESUMEN DE VECTORIZACIÓN
# ================================================================================
#
# ✅ Directorio: data_example
# ✅ Artículos vectorizados: 22
# ✅ Dimensión de vectores: 1340
# ✅ Vectorizador ajustado: True
#
# 💾 Los vectores han sido guardados en los archivos JSON
# 🔄 Ahora puedes usar estos vectores en news_update_&_process.py
#
# ================================================================================
